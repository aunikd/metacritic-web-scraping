# %% [markdown]
# The code uses web scraping to retrieve information about the top movies from the Metacritic website, spanning pages from 1 to 42. It employs the BeautifulSoup library to parse HTML content, extracting movie titles and their respective positions on the page. The collected data, including movie positions and titles, is stored in a list and limited to the first 1000 entries.

# %%
import requests
from bs4 import BeautifulSoup

def retrieve_top_movies_data(begin_page, conclude_page):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    }

    all_films = []

    for current_page in range(begin_page, conclude_page + 1):
        url = f"https://www.metacritic.com/browse/movie/?releaseYearMin=1910&releaseYearMax=2023&page={current_page}"
        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            soup = BeautifulSoup(response.content, "html.parser")
            film_titles = soup.find_all("h3", class_="c-finderProductCard_titleHeading")

            for idx, title_heading in enumerate(film_titles, start=(current_page - 1)):
                title_span = title_heading.find("span", class_="c-finderProductCard_title")
                film_title = title_span.text.strip() if title_span else title_heading.text.strip()
                all_films.append({"Position": idx, "Title": film_title})
        else:
            print(f"Error: Unable to retrieve the page {current_page} (Status code: {response.status_code})")

        if len(all_films) >= 1010:
            break

    return all_films[:1010]

if __name__ == "__main__":
    starting_page_number = 1
    concluding_page_number = 42
    films_data = retrieve_top_movies_data(starting_page_number, concluding_page_number)
    print(films_data)
# Out:
# [{'Position': 0, 'Title': '1. Dekalog (1988)'}, {'Position': 1, 'Title': '2. The Godfather'}, {'Position': 2, 'Title': '3. The Conformist'}, {'Position': 3, 'Title': '4. The Leopard (re-release)'}, {'Position': 4, 'Title': '5. Lawrence of Arabia (re-release)'}, {'Position': 5, 'Title': '6. Citizen Kane'}, {'Position': 6, 'Title': '7. Boyhood'}, {'Position': 7, 'Title': '8. Tokyo Story'}, {'Position': 8, 'Title': '9. Three Colors: Red'}, {'Position': 9, 'Title': '10. Rear Window'}, {'Position': 10, 'Title': '11. Casablanca'}, {'Position': 11, 'Title': '12. Vertigo'}, {'Position': 12, 'Title': '13. Notorious'}, {'Position': 13, 'Title': '14. Fanny and Alexander (re-release)'}, {'Position': 14, 'Title': "15. Singin' in the Rain"}, {'Position': 15, 'Title': '16. Playtime'}, {'Position': 16, 'Title': '17. Army of Shadows'}, {'Position': 17, 'Title': '18. City Lights'}, {'Position': 18, 'Title': '19. Moonlight'}, {'Position': 19, 'Title': '20. Intolerance'}, {'Position': 20, 'Title': '21. The Rules of the Game'}, {'Position': 21, 'Title': '22. Pinocchio'}, {'Position': 22, 'Title': '23. Touch of Evil'}, {'Position': 23, 'Title': '24. Seven Samurai'}, {'Position': 1, 'Title': '25. The Wild Bunch'}, {'Position': 2, 'Title': '26. Au hasard Balthazar'}, {'Position': 3, 'Title': '27. The Lady Vanishes'}, {'Position': 4, 'Title': '28. Pépé le Moko (re-release)'}, {'Position': 5, 'Title': '29. The Treasure of the Sierra Madre'}, {'Position': 6, 'Title': "30. Pan's Labyrinth"}, {'Position': 7, 'Title': '31. Some Like It Hot'}, {'Position': 8, 'Title': '32. North by Northwest'}, {'Position': 9, 'Title': '33. Hoop Dreams'}, {'Position': 10, 'Title': '34. Rashomon'}, {'Position': 11, 'Title': '35. The Passion of Joan of Arc'}, {'Position': 12, 'Title': '36. All About Eve'}, {'Position': 13, 'Title': '37. Metropolis (re-release)'}, {'Position': 14, 'Title': '38. Jules and Jim'}, {'Position': 15, 'Title': '39. My Left Foot'}, {'Position': 16, 'Title': '40. The Night of the Hunter'}, {'Position': 17, 'Title': '41. Ran'}, {'Position': 18, 'Title': '42. The Third Man'}, {'Position': 19, 'Title': '43. Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# 984. In My Room
# 985. Mishima: A Life in Four Chapters
# 986. Pride and Prejudice
# 987. In the Heights
# 988. Blood Simple
# 989. Oslo, August 31st
# 990. The Witch
# 991. Looper
# 992. Graduation
# 993. Kubo and the Two Strings
# 994. The Other Side of Hope
# 995. The Vast of Night
# 996. A Fantastic Woman
# 997. Momma's Man
# 998. Old Joy
# 999. You Were Never Really Here
# 1,000. In the Name of the Father
# 1,001. The Eternal Memory
# 1,002. Ballast
# 1,003. Volver
# 1,004. The Square
# 1,005. Widows
# 1,006. Love After Love
# 1,007. Synonyms
# 1,008. A Ghost Story

# %% [markdown]
# The code iterates through each film entry in the films_data list and modifies the 'Title' key by removing the first word before a space if present. This is done to extract more concise titles, updating the 'Title' key with the modified version. The final list, films_data, reflects the movies with adjusted titles.

# %%
for film in films_data:
    
    first_space_index = film['Title'].find(" ")

    if first_space_index != -1:
        
        modified_title = film['Title'][first_space_index + 1:]
    else:
        
        modified_title = film['Title']

    film['Title'] = modified_title

print(films_data)
# Out:
# [{'Position': 0, 'Title': 'Dekalog (1988)'}, {'Position': 1, 'Title': 'The Godfather'}, {'Position': 2, 'Title': 'The Conformist'}, {'Position': 3, 'Title': 'The Leopard (re-release)'}, {'Position': 4, 'Title': 'Lawrence of Arabia (re-release)'}, {'Position': 5, 'Title': 'Citizen Kane'}, {'Position': 6, 'Title': 'Boyhood'}, {'Position': 7, 'Title': 'Tokyo Story'}, {'Position': 8, 'Title': 'Three Colors: Red'}, {'Position': 9, 'Title': 'Rear Window'}, {'Position': 10, 'Title': 'Casablanca'}, {'Position': 11, 'Title': 'Vertigo'}, {'Position': 12, 'Title': 'Notorious'}, {'Position': 13, 'Title': 'Fanny and Alexander (re-release)'}, {'Position': 14, 'Title': "Singin' in the Rain"}, {'Position': 15, 'Title': 'Playtime'}, {'Position': 16, 'Title': 'Army of Shadows'}, {'Position': 17, 'Title': 'City Lights'}, {'Position': 18, 'Title': 'Moonlight'}, {'Position': 19, 'Title': 'Intolerance'}, {'Position': 20, 'Title': 'The Rules of the Game'}, {'Position': 21, 'Title': 'Pinocchio'}, {'Position': 22, 'Title': 'Touch of Evil'}, {'Position': 23, 'Title': 'Seven Samurai'}, {'Position': 1, 'Title': 'The Wild Bunch'}, {'Position': 2, 'Title': 'Au hasard Balthazar'}, {'Position': 3, 'Title': 'The Lady Vanishes'}, {'Position': 4, 'Title': 'Pépé le Moko (re-release)'}, {'Position': 5, 'Title': 'The Treasure of the Sierra Madre'}, {'Position': 6, 'Title': "Pan's Labyrinth"}, {'Position': 7, 'Title': 'Some Like It Hot'}, {'Position': 8, 'Title': 'North by Northwest'}, {'Position': 9, 'Title': 'Hoop Dreams'}, {'Position': 10, 'Title': 'Rashomon'}, {'Position': 11, 'Title': 'The Passion of Joan of Arc'}, {'Position': 12, 'Title': 'All About Eve'}, {'Position': 13, 'Title': 'Metropolis (re-release)'}, {'Position': 14, 'Title': 'Jules and Jim'}, {'Position': 15, 'Title': 'My Left Foot'}, {'Position': 16, 'Title': 'The Night of the Hunter'}, {'Position': 17, 'Title': 'Ran'}, {'Position': 18, 'Title': 'The Third Man'}, {'Position': 19, 'Title': 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb'}, {'Position': 20, 'Title': 'Quo Vadis, Aida?'}, {'Position': 21, 'Title': 'Rififi (re-release)'}, {'Position': 22, 'Title': 'Psycho'}, {'Position': 23, 'Title': 'Gone with the Wind'}, {'Position': 24, 'Title': '4 Months, 3 Weeks and 2 Days'}, {'Position': 2, 'Title': 'Battleship Potemkin'}, {'Position': 3, 'Title': 'A Streetcar Named Desire'}, {'Position': 4, 'Title': 'The Maltese Falcon'}, {'Position': 5, 'Title': 'American Graffiti'}, {'Position': 6, 'Title': '12 Angry Men'}, {'Position': 7, 'Title': 'Dumbo'}, {'Position': 8, 'Title': 'Roma'}, {'Position': 9, 'Title': 'Man with a Movie Camera'}, {'Position': 10, 'Title': 'Parasite'}, {'Position': 11, 'Title': 'Spirited Away'}, {'Position': 12, 'Title': 'Toy Story'}, {'Position': 13, 'Title': 'Summer of Soul (...Or, When the Revolution Could Not Be Televised)'}, {'Position': 14, 'Title': 'The Shop Around the Corner'}, {'Position': 15, 'Title': "Rosemary's Baby"}, {'Position': 16, 'Title': '12 Years a Slave'}, {'Position': 17, 'Title': 'Manchester by the Sea'}, {'Position': 18, 'Title': 'The Battle of Algiers'}, {'Position': 19, 'Title': 'Killer of Sheep'}, {'Position': 20, 'Title': 'Nashville'}, {'Position': 21, 'Title': 'Red River'}, {'Position': 22, 'Title': 'The Philadelphia Story'}, {'Position': 23, 'Title': 'Sansho the Bailiff'}, {'Position': 24, 'Title': 'Ratatouille'}, {'Position': 25, 'Title': 'The Grapes of Wrath'}, {'Position': 3, 'Title': 'Snow White and the Seven Dwarfs'}, {'Position': 4, 'Title': 'Children of Paradise (1945)'}, {'Position': 5, 'Title': 'Mean Streets'}, {'Position': 6, 'Title': "A Hard Day's Night (re-release)"}, {'Position': 7, 'Title': 'The Lady Eve'}, {'Position': 8, 'Title': 'Gravity'}, {'Position': 9, 'Title': 'Fantasia'}, {'Position': 10, 'Title': 'Beauty and the Beast'}, {'Position': 11, 'Title': 'Small Axe: Lovers Rock'}, {'Position': 12, 'Title': 'The Bride of Frankenstein'}, {'Position': 13, 'Title': "Don't Look Now"}, {'Position': 14, 'Title': 'The Soc ...

# %%
import re
import unicodedata

def filter_title(input_string):

    remove_brackets = re.sub(r'[\[\](){}<>]', '', input_string)
    remove_special = remove_brackets.lower().replace("’", "").replace(":", "").replace("?", "").replace("&", "").replace(".", "").replace(",", "").replace("$", "").replace("'", "").replace("–", "")
    new_string=remove_special.replace("  ", " ").replace(" ", "-")
    nfkd_form = unicodedata.normalize('NFKD', new_string)
    return re.sub(r'[\u0300-\u036F]', '', nfkd_form)

# %% [markdown]
# The code defines a function, fetch_metacritic_info, to scrape Metacritic for director and cast information of a given movie title. The generate_movie_dict function iterates through a list of movie titles, formats them for URL usage, and builds a dictionary (movie_dict) containing director and main cast details obtained from Metacritic. The resulting dictionary provides a structured representation of movie information with modified titles, directors, and main cast members.

# %%
import requests
import re
from bs4 import BeautifulSoup

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36'}

def fetch_metacritic_info(movie_title):
    base_url = "https://www.metacritic.com/movie/"
    credits_url = f"{base_url}{movie_title.lower().replace(' ', '-')}/credits/"

    view_all_page = requests.get(credits_url, headers=headers)

    if view_all_page.url != credits_url and '/credits/' not in view_all_page.url:
        credits_url = view_all_page.url + 'credits/'
        view_all_page = requests.get(credits_url, headers=headers)


    view_all_soup = BeautifulSoup(view_all_page.content, "html.parser")

    credit_tables_list = view_all_soup.find_all('div', class_="c-productCredits g-outer-spacing-bottom-xlarge")

    directed_by_tags = []

    for credit_table in credit_tables_list:
        if "Directed By" in credit_table.get_text().strip():
            director_names = [director.get_text().strip() for director in credit_table.find_all('a')]
            directed_by_tags.extend(director_names)
            #print(directed_by_tags)

    cast_list = []

    for credit_table in credit_tables_list:
        if "Cast" in credit_table.get_text().strip():
            cast_names = [cast.get_text().strip() for cast in credit_table.find_all('a')]
            cast_list.extend(cast_names)

    movie_info_dict = {
        'Director': directed_by_tags,
        'Cast': cast_list
    }

    return movie_info_dict

def generate_movie_dict(movie_titles):
    movie_dict = {}

    for title_info in movie_titles:

        title = title_info["Title"]
        formatted_title= filter_title(title)
        print(formatted_title)
        movie_info = fetch_metacritic_info(formatted_title)

        formatted_movie_info = {
            'Director': movie_info['Director'],
            'Main Cast': movie_info['Cast']
        }

        movie_dict[title] = formatted_movie_info

    return movie_dict

movie_dict = generate_movie_dict(films_data)
# Out:
# dekalog-1988
# the-godfather
# the-conformist
# the-leopard-re-release
# lawrence-of-arabia-re-release
# citizen-kane
# boyhood
# tokyo-story
# three-colors-red
# rear-window
# casablanca
# vertigo
# notorious
# fanny-and-alexander-re-release
# singin-in-the-rain
# playtime
# army-of-shadows
# city-lights
# moonlight
# intolerance
# the-rules-of-the-game
# pinocchio
# touch-of-evil
# seven-samurai
# the-wild-bunch
# au-hasard-balthazar
# the-lady-vanishes
# pepe-le-moko-re-release
# the-treasure-of-the-sierra-madre
# pans-labyrinth
# some-like-it-hot
# north-by-northwest
# hoop-dreams
# rashomon
# the-passion-of-joan-of-arc
# all-about-eve
# metropolis-re-release
# jules-and-jim
# my-left-foot
# the-night-of-the-hunter
# ran
# the-third-man
# dr-strangelove-or-how-i-learned-to-stop-worrying-and-love-the-bomb
# quo-vadis-aida
# rififi-re-release
# psycho
# gone-with-the-wind
# 4-months-3-weeks-and-2-days
# battleship-potemkin
# a-streetcar-named-desire
# the-maltese-falcon
# american-graffiti
# 12-angry-men
# dumbo
# roma
# man-with-a-movie-camera
# parasite
# spirited-away
# toy-story
# summer-of-soul-or-when-the-revolution-could-not-be-televised
# the-shop-around-the-corner
# rosemarys-baby
# 12-years-a-slave
# manchester-by-the-sea
# the-battle-of-algiers
# killer-of-sheep
# nashville
# red-river
# the-philadelphia-story
# sansho-the-bailiff
# ratatouille
# the-grapes-of-wrath
# snow-white-and-the-seven-dwarfs
# children-of-paradise-1945
# mean-streets
# alexandra
# naked
# the-host
# all-is-forgiven-2007
# the-departure
# restrepo
# women-on-the-verge-of-a-nervous-breakdown
# grisbi-re-release
# starless-dreams
# das-boot
# support-the-girls
# stalker
# the-iron-giant
# wont-you-be-my-neighbor
# passing-strange
# meeks-cutoff
# the-long-day-closes
# fruitvale-station
# rachel-getting-married
# the-last-days
# watchers-of-the-sky
# everybody-wants-some!!
# since-otar-left
# paragraph-175
# sound-and-fury
# the-circle
# atlantic-city
# the-handmaiden
# sling-blade
# evangelion-30+10-thrice-upon-a-time
# eo
# slumdog-millionaire
# juliet-of-the-spirits
# beyond-utopia
# black-is-king
# the-work
# a-christmas-tale
# waking-life
# giant
# out-of-sight
# brazil
# the-dark-knight
# in-the-shadow-of-the-moon
# the-big-risk
# get-on-the-bus
# 76-days
# shin-ultraman
# the-last-waltz
# are-you-there-god-its-me-margaret
# the-truffle-hunters
# children-of-men
# broadcast-news
# revanche
# king-country
# the-man-without-a-past
# american-movie
# husbands-and-wives
# after-the-storm
# moonrise-kingdom
# through-a-glass-darkly
# calle-54
# horse-money
# up-the-yangtze
# farewell-my-concubine
# star-wars-episode-viii---the-last-jedi
# high-hopes
# limelight
# mcqueen
# the-black-stallion
# earth-mama
# booksmart
# wise-blood
# writing-with-fire
# small-axe-red-white-and-blue
# ascension
# lantana
# the-friends-of-eddie-coyle
# reality
# seraphine
# oliver-twist
# 49-up
# bpm-beats-per-minute
# the-joy-luck-club
# withnail-i
# the-postman-always-rings-twice
# to-leslie
# american-beauty
# beanpole
# kagemusha
# blade-runner
# harmonium
# bob-dylan-dont-look-back
# fireworks-wednesday-2006
# all-the-presidents-men
# prizzis-honor
# far-from-heaven
# heart-of-a-dog
# no-mans-land
# lagaan-once-upon-a-time-in-india
# decision-to-leave
# aferim!
# war-witch
# 2001-a-space-odyssey
# toy-story-4
# darwins-nightmare
# the-fabelmans
# aliens
# my-winnipeg
# on-the-record
# in-my-room
# mishima-a-life-in-four-chapters
# pride-and-prejudice
# in-the-heights
# blood-simple
# oslo-august-31st
# the-witch
# looper
# graduation
# kubo-and-the-two-strings
# the-other-side-of-hope
# the-vast-of-night
# a-fantastic-woman
# mommas-man
# old-joy
# you-were-never-really-here
# in-the-name-of-the-father
# the-eternal-memory
# ballast
# volver
# the-square
# widows
# love-after-love
# synonyms
# a-ghost-story

# %% [markdown]
# The code uses the CSV module to write movie information from the movie_dict dictionary to a CSV file named "Movies_info.csv". It creates a CSV writer with specified field names, writes the header, and iterates through the movie dictionary to write each movie's title, directors, and main cast to the CSV file. Finally, it prints a confirmation message indicating the successful writing of movie data to the specified file.

# %%
import csv


data_path = "Movies_info.csv"
field_names = ["Movie Title", "Director", "Main Cast"]


with open(data_path, "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=field_names)

    writer.writeheader()

    for movie_title, movie_info in movie_dict.items():
        director_str = ", ".join(movie_info["Director"])
        cast_str = ", ".join(movie_info["Main Cast"])

        writer.writerow(
            {
                "Movie Title": movie_title,
                "Director": director_str,
                "Main Cast": cast_str,
            }
        )


print(f"Movie data successfully written to: {data_path}")
# Out:
# Movie data successfully written to: Movies_info.csv

# %% [markdown]
# The code defines a function, find_movie_info, that prompts the user to input a movie title, searches for a matching title in the movie_dict dictionary, and prints the corresponding director and main cast information if the movie is found. If the movie is not found, it prints a message indicating that the movie is not in the dataset.

# %%
def find_movie_info():
    user_input = input("Enter the name of a movie: ").strip().lower()

    located_movie = None
    for film_title, film_info in movie_dict.items():
        if user_input in film_title.lower():
            located_movie = film_title
            break

    if located_movie:
        print(f"\nThe director of {located_movie} is: {', '.join(movie_dict[located_movie]['Director'])}")
        print(f"The cast of {located_movie} includes: {', '.join(movie_dict[located_movie]['Main Cast'])}")
    else:
        print("Movie not found.")

# %% [markdown]
# The code defines three functions: get_director_movies, which returns a list of movies directed by a given director; get_collaborations, which returns a dictionary counting collaborations between the director and performers; and explore_people, which prompts the user to enter a director's name, searches for the director in the dataset, and prints the movies directed by the director and their collaborations with performers. If the director is not found, it prints a message indicating that the director is not in the dataset.

# %%
def get_director_movies(director_name, movie_dict):
    directed_movies = []
    for movie_title, movie_info in movie_dict.items():
        if director_name in movie_info['Director']:
            directed_movies.append(movie_title)
    return directed_movies

def get_collaborations(director_name, movie_dict):
    collaborations_count = {}
    for movie_title, movie_info in movie_dict.items():
        if director_name in movie_info['Director']:
            for performer in movie_info['Main Cast']:
                if performer not in collaborations_count:
                    collaborations_count[performer] = 1
                else:
                    collaborations_count[performer] += 1
    return collaborations_count

def explore_people():
    director_query = input("Enter the name of a director (Please use proper upper case for the first character in the name and lowercase for the rest): ").strip()

    located_director = False
    for movie_title, movie_info in movie_dict.items():
        if director_query in movie_info['Director']:
            located_director = True
            director_movies = get_director_movies(director_query, movie_dict)
            collaborations = get_collaborations(director_query, movie_dict)

            print(f"\n{director_query} has directed in:")
            for movie in director_movies:
                print(f"- {movie}")

            print("\nThe director has worked together with these people:")
            for actor, count in collaborations.items():
                print(f"- {actor}: {count} collaborations")

    if not located_director:
        print("Director not found.")

# %% [markdown]
# The code defines a function, calculate_cosine_similarity, that calculates the cosine similarity between the cast lists of two directors using TfidfVectorizer and cosine_similarity from scikit-learn. The cosine_comparison function prompts the user to input the names of two directors and then calculates and prints the cosine similarity between them based on the cast of movies they directed. If one or both directors are not found or are identical, it prints a message and returns a similarity score of 0.0.

# %% [markdown]
# Finally, the code presents a menu to the user, prompting them to choose between checking information about a movie ('movie'), exploring details about people involved in movies ('people'), or comparing directors based on cosine similarity of their cast ('comparison'). It then processes the user's choice and executes the corresponding function or displays an error message for an invalid choice.

# %%
print("What do you want to check on Metacritic? (Please choose 'movie', 'people', or 'comparison')")
choice = input("Your choice: ").lower()

if choice=='movie':
    find_movie_info()

elif choice=='people':
    explore_people()

elif choice=='comparison':
    cosine_comparison()

else:
    print("Invalid choice. Please enter 'movie', 'people', or 'comparison'.")
# Out:
# What do you want to check on Metacritic? (Please choose 'movie', 'people', or 'comparison')
# Invalid choice. Please enter 'movie', 'people', or 'comparison'.
